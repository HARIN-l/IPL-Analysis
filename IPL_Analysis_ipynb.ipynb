# %% [markdown]
# <a href="https://colab.research.google.com/github/HARIN-l/IPL-Analysis/blob/main/IPL_Analysis_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as py
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = py.read_excel("/content/drive/MyDrive/scorecards.xlsx")

# %%
df
# Out:
#        Season  match  inn  for against             Name              Mode  \
# 0        2008      1    1  KKR     RCB       SC Ganguly   c Kallis b Khan
# 1        2008      1    1  KKR     RCB      BB McCullum       BB McCullum
# 2        2008      1    1  KKR     RCB       RT Ponting  c Kumar b Kallis
# 3        2008      1    1  KKR     RCB        DJ Hussey  c White b Noffke
# 4        2008      1    1  KKR     RCB  Mohammad Hafeez           not out
# ...       ...    ...  ...  ...     ...              ...               ...
# 12961    2019     60    2  CSK      MI        SN Thakur     lbw b Malinga
# 12962    2019     60    2  CSK      MI        DL Chahar            Bowler
# 12963    2019     60    2  CSK      MI  Harbhajan Singh            Bowler
# 12964    2019     60    2  CSK      MI      Imran Tahir            Bowler
# 12965    2019     60    1   MI     CSK       SL Malinga            Bowler
#
#          R   B  4s  6s      SR
# 0       10  12   2   0   83.33
# ...

# %%
fire=df.head(21)

# %%
df.head(21)
# Out:
#     Season  match  inn  for against             Name                    Mode  \
# 0     2008      1    1  KKR     RCB       SC Ganguly         c Kallis b Khan
# 1     2008      1    1  KKR     RCB      BB McCullum             BB McCullum
# 2     2008      1    1  KKR     RCB       RT Ponting        c Kumar b Kallis
# 3     2008      1    1  KKR     RCB        DJ Hussey        c White b Noffke
# 4     2008      1    1  KKR     RCB  Mohammad Hafeez                 not out
# 5     2008      1    2  RCB     KKR         R Dravid                b Sharma
# 6     2008      1    2  RCB     KKR         W Jaffer       c Ponting b Dinda
# 7     2008      1    2  RCB     KKR          V Kohli                 b Dinda
# 8     2008      1    2  RCB     KKR        JH Kallis      c Kartik b Agarkar
# 9     2008      1    2  RCB     KKR         CL White        c Saha b Agarkar
# 10    2008      1    2  RCB     KKR       MV Boucher      c Kartik b Ganguly
# ...

# %%
df["R"].head(21)>20
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19    False
# 20     True
# Name: R, dtype: bool

# %%
df["B"].head(21)>20
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# Name: B, dtype: bool

# %%
df["4s"].head(21)>20
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: 4s, dtype: bool

# %%
df["6s"].head(21)>20
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: 6s, dtype: bool

# %%
df[(df["R"] < 12) & (df["R"] > 25)]
# Out:
# Empty DataFrame
# Columns: [Season, match, inn, for, against, Name, Mode, R, B, 4s, 6s, SR]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['match']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'match'}, axis=1)
              .sort_values('match', ascending=True))
  xs = counted['match']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_2.sort_values('match', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('match')
_ = plt.ylabel('count()')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['index']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'index'}, axis=1)
              .sort_values('index', ascending=True))
  xs = counted['index']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_0.sort_values('index', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('count()')

# %%
df
# Out:
#        Season  match  inn  for against             Name              Mode  \
# 0        2008      1    1  KKR     RCB       SC Ganguly   c Kallis b Khan
# 1        2008      1    1  KKR     RCB      BB McCullum       BB McCullum
# 2        2008      1    1  KKR     RCB       RT Ponting  c Kumar b Kallis
# 3        2008      1    1  KKR     RCB        DJ Hussey  c White b Noffke
# 4        2008      1    1  KKR     RCB  Mohammad Hafeez           not out
# ...       ...    ...  ...  ...     ...              ...               ...
# 12961    2019     60    2  CSK      MI        SN Thakur     lbw b Malinga
# 12962    2019     60    2  CSK      MI        DL Chahar            Bowler
# 12963    2019     60    2  CSK      MI  Harbhajan Singh            Bowler
# 12964    2019     60    2  CSK      MI      Imran Tahir            Bowler
# 12965    2019     60    1   MI     CSK       SL Malinga            Bowler
#
#          R   B  4s  6s      SR
# 0       10  12   2   0   83.33
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Season']
  ys = series['inn']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Season', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Season')
_ = plt.ylabel('inn')

# %%
from matplotlib import pyplot as plt
df['R'].plot(kind='line', figsize=(8, 4), title='R')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='R', y='B', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.figure(figsize=(13.5,8))
plt.bar(list(df['R'].value_counts()[0:5].keys()),list(df['R'].value_counts()[0:5]))
plt.show()

# %%
plt.figure(figsize=(13.5,8))
plt.bar(list(df['4s'].value_counts()[0:5].keys()),list(df['4s'].value_counts()[0:5]))
plt.show()

# %%
df2 = py.read_excel("/content/drive/MyDrive/season.xlsx")

# %%
df2
# Out:
#               Player  Mat  Inns  NO  Runs  HS    Ave  BF      SR  100  50  0  \
# 0     A Ashish Reddy   12    10   4   125  36  20.83  89  140.44    0   0  0
# 1     A Ashish Reddy    6     5   2    73  22  24.33  46  158.69    0   0  0
# 2     A Ashish Reddy    9     5   1    35  10   8.75  29  120.68    0   0  0
# 3     A Ashish Reddy    4     3   1    47  32  23.50  29  162.06    0   0  0
# 4         A Chandila    8     1   1     4   4   0.00   6   66.66    0   0  0
# ...              ...  ...   ...  ..   ...  ..    ...  ..     ...  ...  .. ..
# 1832          Z Khan   11     8   4    34  17   8.50  43   79.06    0   0  1
# 1833          Z Khan   16     5   3    12  11   6.00  17   70.58    0   0  2
# 1834          Z Khan   15     2   0    21  21  10.50  24   87.50    0   0  1
# 1835          Z Khan   12     2   0     6   4   3.00  13   46.15    0   0  0
# 1836          Z Khan   11     3   2     4   2   4.00  13   30.76    0   0  0
#
#       4s  6s  Season  NO in HS
# ...

# %%
df2.head(11)
# Out:
#             Player  Mat  Inns  NO  Runs  HS    Ave  BF      SR  100  50  0  \
# 0   A Ashish Reddy   12    10   4   125  36  20.83  89  140.44    0   0  0
# 1   A Ashish Reddy    6     5   2    73  22  24.33  46  158.69    0   0  0
# 2   A Ashish Reddy    9     5   1    35  10   8.75  29  120.68    0   0  0
# 3   A Ashish Reddy    4     3   1    47  32  23.50  29  162.06    0   0  0
# 4       A Chandila    8     1   1     4   4   0.00   6   66.66    0   0  0
# 5       A Chandila    4     1   1     0   0   0.00   1    0.00    0   0  0
# 6         A Chopra    5     5   0    42  24   8.40  52   80.76    0   0  0
# 7         A Chopra    2     1   0    11  11  11.00  19   57.89    0   0  0
# 8      A Choudhary    5     3   2    25  15  25.00  20  125.00    0   0  0
# 9      A Dananjaya    1     1   1     4   4   0.00   5   80.00    0   0  0
# 10      A Flintoff    3     3   1    62  24  31.00  53  116.98    0   0  0
#
#     4s  6s  Season  NO in HS
# 0    9   4    2013         1
# ...

# %%
ice=df2.head(11)
