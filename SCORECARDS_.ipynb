# %% [markdown]
# <a href="https://colab.research.google.com/github/HARIN-l/IPL-Analysis/blob/main/SCORECARDS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("/content/drive/MyDrive/scorecards.xlsx")

# %%
df
# Out:
#        Season  match  inn  for against             Name              Mode  \
# 0        2008      1    1  KKR     RCB       SC Ganguly   c Kallis b Khan
# 1        2008      1    1  KKR     RCB      BB McCullum       BB McCullum
# 2        2008      1    1  KKR     RCB       RT Ponting  c Kumar b Kallis
# 3        2008      1    1  KKR     RCB        DJ Hussey  c White b Noffke
# 4        2008      1    1  KKR     RCB  Mohammad Hafeez           not out
# ...       ...    ...  ...  ...     ...              ...               ...
# 12961    2019     60    2  CSK      MI        SN Thakur     lbw b Malinga
# 12962    2019     60    2  CSK      MI        DL Chahar            Bowler
# 12963    2019     60    2  CSK      MI  Harbhajan Singh            Bowler
# 12964    2019     60    2  CSK      MI      Imran Tahir            Bowler
# 12965    2019     60    1   MI     CSK       SL Malinga            Bowler
#
#          R   B  4s  6s      SR
# 0       10  12   2   0   83.33
# ...

# %%
df.head(6)
# Out:
#    Season  match  inn  for against             Name              Mode    R  \
# 0    2008      1    1  KKR     RCB       SC Ganguly   c Kallis b Khan   10
# 1    2008      1    1  KKR     RCB      BB McCullum       BB McCullum  158
# 2    2008      1    1  KKR     RCB       RT Ponting  c Kumar b Kallis   20
# 3    2008      1    1  KKR     RCB        DJ Hussey  c White b Noffke   12
# 4    2008      1    1  KKR     RCB  Mohammad Hafeez           not out    5
# 5    2008      1    2  RCB     KKR         R Dravid          b Sharma    2
#
#     B  4s  6s      SR
# 0  12   2   0   83.33
# 1  73  10  13  216.43
# 2  20   1   1     100
# 3  12   1   0     100
# 4   3   1   0  166.66
# 5   3   0   0   66.66

# %%
fire=df.head(6)

# %%
df["R"].head(6)>20
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: R, dtype: bool

# %%
df["B"].head(6)>20
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: B, dtype: bool

# %%
df["4s"].head(6)>20
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: 4s, dtype: bool

# %%
df["6s"].head(6)>20
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: 6s, dtype: bool

# %%
df["SR"].head(6)>20
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# Name: SR, dtype: bool

# %%
plt.figure(figsize=(13.5,8))
plt.bar(list(df['4s'].value_counts()[0:6].keys()),list(df['6s'].value_counts()[0:6]))
plt.show()

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='4s', y='6s', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['4s'].plot(kind='line', figsize=(8, 4), title='6s')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df["R"].head(6)>20
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: R, dtype: bool

# %%
df["B"].head(6)>20
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: B, dtype: bool

# %% [markdown]
# THE BAR graph     ( R IN 0-6 &  B IN 0-6)
#
# > Add blockquote

# %%
plt.figure(figsize=(13.5,8))
plt.bar(list(df['R'].value_counts()[0:6].keys()),list(df['B'].value_counts()[0:6]))
plt.show()

# %% [markdown]
# THE BAR graph ( R IN 0-6 & B IN 0-6)

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='R', y='B', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# THE SCATTER graph ( R IN 0-6 & B IN 0-6)

# %%
from matplotlib import pyplot as plt
df['R'].plot(kind='line', figsize=(8, 4), title='B')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# THE LINE graph ( R IN 0-6 & B IN 0-6)

# %%
df[(df["R"] < 12) & (df["R"] > 25)]
# Out:
# Empty DataFrame
# Columns: [Season, match, inn, for, against, Name, Mode, R, B, 4s, 6s, SR]
# Index: []
