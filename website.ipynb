# %% [markdown]
# <a href="https://colab.research.google.com/github/HARIN-l/IPL-Analysis/blob/main/website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/drive/MyDrive/website_wata.csv")

# %%
df
# Out:
#       Page Views  Session Duration  Bounce Rate Traffic Source  Time on Page  \
# 0              5         11.051381     0.230652        Organic      3.890460
# 1              4          3.429316     0.391001         Social      8.478174
# 2              4          1.621052     0.397986        Organic      9.636170
# 3              5          3.629279     0.180458        Organic      2.071925
# 4              5          4.235843     0.291541           Paid      1.960654
# ...          ...               ...          ...            ...           ...
# 1995           1          2.724513     0.207187       Referral      1.324206
# 1996           3          0.392856     0.095559        Organic      3.824416
# 1997           4          9.899823     0.446622        Organic      1.288675
# 1998           3          0.393319     0.278340           Paid      5.037584
# 1999           3          0.882638     0.338026         Direct      5.186908
#
#       Previous Visits  Conversion Rate
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: 0.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-36beb63e240a> in <cell line: 2>()
#       1 plt.figure(figsize=(13.5,8))
# ...

# %%
eat=['Session Duration','Bounce Rate','Traffic Source','Time on Page']

# %%
setone=df.loc[0:100,eat]

# %%
setone.reset_index(drop=True, inplace=True)
setone.loc[50:75]
# Out:
#     Session Duration  Bounce Rate Traffic Source  Time on Page
# 50          0.423207     0.844939        Organic      0.727810
# 51          0.151645     0.189229           Paid      3.970197
# 52          3.556002     0.160530       Referral      3.154550
# 53          5.355408     0.386125        Organic      3.834073
# 54          5.619210     0.358930        Organic      3.910938
# 55          3.403933     0.048202        Organic      4.879187
# 56          9.238373     0.526356        Organic      5.415282
# 57          2.146208     0.159206        Organic     14.338516
# 58          7.353770     0.222897        Organic      9.840271
# 59         10.308497     0.646390       Referral      5.316900
# 60          5.635041     0.054179       Referral      2.769737
# 61          1.112142     0.293754        Organic      2.814259
# 62          0.655273     0.268241       Referral      0.370603
# 63          2.383016     0.083114           Paid      1.586550
# ...

# %%
setone = setone_0_100.iloc[50:75]


plt.plot(setone['Bounce Rate'], setone['Bounce Rate'])
plt.title('Graph of Columns Bounce Rate vs Bounce Rate from Rows 50-75 of the 0-100 setone')
plt.xlabel('Bounce Rate')
plt.ylabel('Bounce Rate')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-d1af856499f7> in <cell line: 1>()
# ----> 1 setone = setone_0_100.iloc[50:75]
#       2
#       3
#       4 plt.plot(setone['Bounce Rate'], setone['Bounce Rate'])
#       5 plt.title('Graph of Columns Bounce Rate vs Bounce Rate from Rows 50-75 of the 0-100 setone')
#
# NameError: name 'setone_0_100' is not defined

# %%
top_60 = df['Bounce Rate'].value_counts().nlargest(15)

plt.figure(figsize=(15,10))
plt.bar(top_60.index, top_60.values)
plt.xlabel('Bounce Rate')
plt.ylabel('Frequency')
plt.title('Top 60 Most Frequent Bounce Rate')
plt.show()

# %%
top_60 = df['Traffic Source'].value_counts().nlargest(15)

plt.figure(figsize=(15,10))
plt.bar(top_60.index, top_60.values)
plt.xlabel('Traffic Source')
plt.ylabel('Frequency')
plt.title('Top 60 Most Frequent Traffic Source')
plt.show()

# %%
top_60 = df['Session Duration'].value_counts().nlargest(15)

plt.figure(figsize=(15,10))
plt.bar(top_60.index, top_60.values)
plt.xlabel('Session Duration')
plt.ylabel('Frequency')
plt.title('Top 60 Most Frequent Session Duration')
plt.show()

# %%
settwo=df.loc[100:250,eat]

# %%
settwo.reset_index(drop=True, inplace=True)
settwo.loc[50:75]
# Out:
#     Session Duration  Bounce Rate Traffic Source  Time on Page
# 50          1.200608     0.031380         Direct      9.049868
# 51          3.152601     0.139460           Paid      4.376876
# 52          4.244017     0.246271         Social      7.275035
# 53          4.153208     0.177798        Organic      3.549808
# 54          2.139279     0.399458           Paid      2.353521
# 55          4.995178     0.394311         Social      5.883735
# 56          1.723843     0.021723         Direct      1.346004
# 57          0.396759     0.254945           Paid      5.419541
# 58          2.493381     0.115203       Referral      0.207017
# 59          9.128559     0.104062        Organic      0.846540
# 60          4.725017     0.593564        Organic      1.740480
# 61          2.593235     0.156005        Organic      3.016579
# 62          3.122211     0.113946        Organic      6.081980
# 63          8.001964     0.322042        Organic      1.934706
# ...

# %%
top_55 = df['Bounce Rate'].value_counts().nlargest(10)

plt.figure(figsize=(15,10))
plt.bar(top_55.index, top_55.values)
plt.xlabel('Bounce Rate')
plt.ylabel('Frequency')
plt.title('Top 55 Most Frequent Bounce Rate')
plt.show()

# %%
top_55 = df['Traffic Source'].value_counts().nlargest(10)

plt.figure(figsize=(15,10))
plt.bar(top_55.index, top_55.values)
plt.xlabel('Traffic Source')
plt.ylabel('Frequency')
plt.title('Top 55 Most Frequent Traffic Source')
plt.show()

# %%
setone.reset_index(drop=True, inplace=True)
setone.loc[75:110]
# Out:
#      Session Duration  Bounce Rate Traffic Source  Time on Page
# 75           1.780135     0.273504        Organic      1.223317
# 76           7.467529     0.509322           Paid      6.363472
# 77           1.892602     0.139796        Organic      3.103390
# 78           0.964917     0.485452       Referral      4.377897
# 79           0.458855     0.369619           Paid      1.243047
# 80           0.011256     0.183127        Organic      5.900334
# 81           2.278871     0.475961       Referral      5.027114
# 82           0.340033     0.314159           Paid      3.714917
# 83           1.491398     0.124971        Organic      5.792329
# 84           2.669471     0.397080        Organic      2.260659
# 85           0.967590     0.232243        Organic      2.650401
# 86           0.577931     0.645711        Organic      2.572884
# 87           4.471255     0.147181         Direct      0.791936
# 88           8.800593     0.289880           Paid      2.997510
# ...

# %%
df2 = pd.read_csv("/content/drive/MyDrive/tiktok_dataset.csv")

# %%
df2
# Out:
#            # claim_status    video_id  video_duration_sec  \
# 0          1        claim  7017666017                  59
# 1          2        claim  4014381136                  32
# 2          3        claim  9859838091                  31
# 3          4        claim  1866847991                  25
# 4          5        claim  7105231098                  19
# ...      ...          ...         ...                 ...
# 19377  19378          NaN  7578226840                  21
# 19378  19379          NaN  6079236179                  53
# 19379  19380          NaN  2565539685                  10
# 19380  19381          NaN  2969178540                  24
# 19381  19382          NaN  8132759688                  13
#
#                                 video_transcription_text verified_status  \
# 0      someone shared with me that drone deliveries a...    not verified
# 1      someone shared with me that there are more mic...    not verified
# ...

# %%
video=['video_duration_sec','verified_status','author_ban_status','video_view_count']

# %%
one=df2.loc[0:100,video]

# %%
one.reset_index(drop=True, inplace=True)
one.loc[25:75]
# Out:
#     video_duration_sec verified_status author_ban_status  video_view_count
# 25                  33    not verified            active          506061.0
# 26                  10    not verified      under review           50892.0
# 27                  22    not verified      under review          812056.0
# 28                  21    not verified            active          677855.0
# 29                  48    not verified            active           74323.0
# 30                  55    not verified            active          573518.0
# 31                  21    not verified            banned          376637.0
# 32                  23    not verified            active          781955.0
# 33                  33    not verified            active          822795.0
# 34                  10    not verified            active          418750.0
# 35                  12    not verified            active          535825.0
# ...

# %%
plt.figure(figsize=(13.5,8))
plt.bar(list(df2['verified_status'].value_counts()[0:6].keys()),list(df2['verified_status'].value_counts()[0:6]))
plt.show()

# %%
plt.figure(figsize=(13.5,8))
plt.bar(list(df2['verified_status'].value_counts()[0:6].keys()),list(df['Previous Visits'].value_counts()[0:6]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-f6c8d870cca7> in <cell line: 2>()
#       1 plt.figure(figsize=(13.5,8))
# ----> 2 plt.bar(list(df2['verified_status'].value_counts()[0:6].keys()),list(df['Previous Visits'].value_counts()[0:6]))
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# ...

# %%
plt.figure(figsize=(13.5,8))
plt.bar(list(df['Previous Visits'].value_counts()[0:6].keys()),list(df['Previous Visits'].value_counts()[0:6]))
plt.show()

# %%
plt.figure(figsize=(13.5,8))
plt.bar(list(df['Traffic Source'].value_counts()[0:15].keys()),list(df['Traffic Source'].value_counts()[0:15]))
plt.show()

# %%
top_15 = df['Traffic Source'].value_counts().nlargest(10)

plt.figure(figsize=(15,10))
plt.bar(top_15.index, top_15.values)
plt.xlabel('Traffic Source')
plt.ylabel('Frequency')
plt.title('Top 15 Most Frequent Traffic Source')
plt.show()

# %%
df
# Out:
#       Page Views  Session Duration  Bounce Rate Traffic Source  Time on Page  \
# 0              5         11.051381     0.230652        Organic      3.890460
# 1              4          3.429316     0.391001         Social      8.478174
# 2              4          1.621052     0.397986        Organic      9.636170
# 3              5          3.629279     0.180458        Organic      2.071925
# 4              5          4.235843     0.291541           Paid      1.960654
# ...          ...               ...          ...            ...           ...
# 1995           1          2.724513     0.207187       Referral      1.324206
# 1996           3          0.392856     0.095559        Organic      3.824416
# 1997           4          9.899823     0.446622        Organic      1.288675
# 1998           3          0.393319     0.278340           Paid      5.037584
# 1999           3          0.882638     0.338026         Direct      5.186908
#
#       Previous Visits  Conversion Rate
# ...
